# %%
import pandas as pd 
import numpy as np
import matplotlib as mtp
import seaborn as sns

# %%
dress_info = pd.read_csv("D:\Data_Science\Project\data\\raw\Dress details.csv")
dress_info.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\RUSHANK\AppData\Local\Temp\ipykernel_31200\1493589987.py:1: SyntaxWarning: invalid escape sequence '\D'
#   dress_info = pd.read_csv("D:\Data_Science\Project\data\\raw\Dress details.csv")
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# ...

# %%
dress_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
dress_info[dress_info.Season.isnull()]  

##929797706
##751364623
# Out:
#       Dress_ID   Style    Price  Rating  Size Season    NeckLine SleeveLength  \
# 183  929797706  Casual      Low     0.0  free    NaN      o-neck         full
# 263  751364623   party  Average     4.8     L    NaN  Sweetheart    sleevless
#
#     Material FabricType Decoration Pattern Type  Recommendation
# 183   cotton        NaN        NaN    patchwork               0
# 263      NaN        NaN      pleat          NaN               1

# %%
dress_info[dress_info['Style'] == 'Casual']
# Out:
#        Dress_ID   Style    Price  Rating  Size  Season   NeckLine  \
# 1    1212192089  Casual      Low     0.0     L  Summer     o-neck
# 6    1220707172  Casual  Average     0.0    XL  Summer     o-neck
# 13   1055411544  Casual      Low     5.0     M  Summer  boat-neck
# 14   1162628131  Casual      Low     0.0  free  Winter  boat-neck
# 20    856178100  Casual      Low     4.3     M  Summer     o-neck
# ..          ...     ...      ...     ...   ...     ...        ...
# 471   964917582  Casual  Average     5.0     L  Summer     o-neck
# 475   713391965  Casual      Low     4.7     M  Spring     o-neck
# 476   532874347  Casual  Average     4.7     M  Summer     v-neck
# 477   655464934  Casual  Average     4.6     L  winter  boat-neck
# 478   919930954  Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength    Material  FabricType Decoration Pattern Type  \
# 1          Petal  microfiber         NaN    ruffles       animal
# ...

# %%
dress_info.groupby('Style')['Season'].apply(lambda x: x.mode().iloc[0])
# Out:
# Style
# Brief       Spring
# Casual      Summer
# Flare       Spring
# Novelty     Summer
# OL          Winter
# Sexy        Summer
# bohemian    Summer
# cute        Summer
# fashion     Summer
# party       Spring
# sexy        Winter
# vintage     Summer
# work        Summer
# Name: Season, dtype: object

# %%
dress_info[dress_info['Style'] == 'Casual']
# Out:
#        Dress_ID   Style    Price  Rating  Size  Season   NeckLine  \
# 1    1212192089  Casual      Low     0.0     L  Summer     o-neck
# 6    1220707172  Casual  Average     0.0    XL  Summer     o-neck
# 13   1055411544  Casual      Low     5.0     M  Summer  boat-neck
# 14   1162628131  Casual      Low     0.0  free  Winter  boat-neck
# 20    856178100  Casual      Low     4.3     M  Summer     o-neck
# ..          ...     ...      ...     ...   ...     ...        ...
# 471   964917582  Casual  Average     5.0     L  Summer     o-neck
# 475   713391965  Casual      Low     4.7     M  Spring     o-neck
# 476   532874347  Casual  Average     4.7     M  Summer     v-neck
# 477   655464934  Casual  Average     4.6     L  winter  boat-neck
# 478   919930954  Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength    Material  FabricType Decoration Pattern Type  \
# 1          Petal  microfiber         NaN    ruffles       animal
# ...

# %%
dress_info['Season'] = dress_info['Season'].fillna(
    dress_info.groupby('Style')['Season'].transform(lambda x: x.mode().iloc[0])
)

##929797706
##751364623

dress_info[dress_info['Dress_ID'] == 751364623]
# Out:
#       Dress_ID  Style    Price  Rating Size  Season    NeckLine SleeveLength  \
# 263  751364623  party  Average     4.8    L  Spring  Sweetheart    sleevless
#
#     Material FabricType Decoration Pattern Type  Recommendation
# 263      NaN        NaN      pleat          NaN               1

# %%
dress_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          479 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
dress_info
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# ...

# %%
dress_info[dress_info['Price'].isnull()]

#662727740
#1090993173
# Out:
#        Dress_ID  Style Price  Rating  Size  Season NeckLine SleeveLength  \
# 255   662727740  party   NaN     4.8  free  Winter   o-neck    sleevless
# 256  1090993173  party   NaN     4.5     L  Summer      NaN         full
#
#     Material FabricType  Decoration Pattern Type  Recommendation
# 255      NaN        NaN  embroidary          NaN               1
# 256      NaN        NaN         NaN          NaN               1

# %%
dress_info[(dress_info['Style'] == 'party') & (dress_info['Size'] == 'L')]
# Out:
#        Dress_ID  Style      Price  Rating Size  Season    NeckLine  \
# 247  1108613896  party  very-high     0.0    L  Winter      v-neck
# 256  1090993173  party        NaN     4.5    L  Summer         NaN
# 260   732184480  party  very-high     4.8    L  Spring  Sweetheart
# 262   579010251  party       High     4.6    L  Spring  slash-neck
# 263   751364623  party    Average     4.8    L  Spring  Sweetheart
# 267   754138176  party  very-high     4.2    L  Winter      v-neck
# 273   618420156  party  very-high     4.7    L  Winter  slash-neck
# 283   736076633  party  very-high     4.9    L  Spring  slash-neck
#
#     SleeveLength    Material FabricType Decoration Pattern Type  \
# 247    sleevless    polyster      tulle    beading          NaN
# 256         full         NaN        NaN        NaN          NaN
# 260    sleevless  microfiber    organza    beading          NaN
# 262    sleevless        silk    chiffon    beading          NaN
# ...

# %%
dress_info.groupby(['Style','Size'])['Price'].apply(lambda x: x.mode().iloc[0])
# Out:
# Style     Size
# Brief     L          Average
#           M          Average
#           XL         Average
#           free       Average
# Casual    L          Average
#           M          Average
#           S          Average
#           XL         Average
#           free           Low
#           s          Average
#           small    very-high
# Flare     free       Average
# Novelty   L          Average
#           M           Medium
#           S          Average
#           free       Average
# OL        M           Medium
# Sexy      L          Average
#           M          Average
#           S          Average
#           free           Low
# bohemian  L          Average
#           M          Average
#           S          Average
#           XL             Low
#           free           Low
# cute      L          Average
#           M          Average
#           S           Medium
#           XL         Average
#           free           Low
# ...

# %%
dress_info['Price'] = dress_info['Price'].fillna(
    dress_info.groupby(['Style', 'Size'])['Price'].transform(lambda x: x.mode().iloc[0])
)

#662727740
#1090993173

# %%
dress_info[dress_info.Dress_ID == 662727740]
# Out:
#       Dress_ID  Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 255  662727740  party  Average     4.8  free  Winter   o-neck    sleevless
#
#     Material FabricType  Decoration Pattern Type  Recommendation
# 255      NaN        NaN  embroidary          NaN               1

# %%
dress_info[dress_info.Dress_ID == 1090993173]
# Out:
#        Dress_ID  Style      Price  Rating Size  Season NeckLine SleeveLength  \
# 256  1090993173  party  very-high     4.5    L  Summer      NaN         full
#
#     Material FabricType Decoration Pattern Type  Recommendation
# 256      NaN        NaN        NaN          NaN               1

# %%
dress_info.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               0
# Rating              0
# Size                0
# Season              0
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %%
dress_info[dress_info.SleeveLength.isnull()]
# Out:
#        Dress_ID Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 319   858212832  cute  Average     4.3     M  Summer      NaN          NaN
# 424  1055149353  Sexy      Low     0.0  free  winter   v-neck          NaN
#
#     Material FabricType Decoration Pattern Type  Recommendation
# 319   cotton    chiffon        NaN        solid               0
# 424   cotton        NaN       lace          NaN               1

# %%
dress_info
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# ...

# %%
sns.scatterplot(dress_info.Material)
# Out:
# <Axes: ylabel='Material'>

# %%
# It seems like sill is mistyped and is clearly a typo 

dress_info.Material = dress_info.Material.replace({
    'sill' : 'silk'
})

# %%
sns.scatterplot(dress_info['Pattern Type'])
# Out:
# <Axes: ylabel='Pattern Type'>

# %%
dress_info['Pattern Type'] = dress_info['Pattern Type'].replace({
    'leapord' : 'leopard'
})
